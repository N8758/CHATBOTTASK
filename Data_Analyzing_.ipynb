# %% [markdown]
# <a href="https://colab.research.google.com/github/N8758/CHATBOTTASK/blob/main/Data_Analyzing_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Project 1: Analyzing Indian Premier League (IPL) Data

# %%
import matplotlib.pyplot as plt

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample IPL Data (You'll need a more comprehensive dataset for real analysis)
data = {
    "season": [2023, 2023, 2023, 2022, 2022, 2022, 2021, 2021, 2021],
    "team1": ['MI', 'CSK', 'RCB', 'MI', 'KXIP', 'CSK', 'DC', 'RCB', 'MI'],
    "team2": ['CSK', 'RCB', 'MI', 'KKR', 'CSK', 'MI', 'MI', 'CSK', 'KKR'],
    "winner": ['MI', 'CSK', 'MI', 'MI', 'KKR', 'CSK', 'DC', 'RCB', 'MI'],
    "city": ['Mumbai', 'Chennai', 'Bangalore', 'Kolkata', 'Chennai', 'Mumbai', 'Delhi', 'Bangalore', 'Kolkata'],
    "player_of_match": ["Rohit Sharma", 'MS Dhoni', 'Virat Kohli', 'Jasprit Bumrah', "Andre Russell", 'Ravindra Jadeja', "Rishabh Pant", 'AB de Villiers', "Kieron Pollard"],
    "runs_scored": [160, 150, 175, 150, 200, 190, 178, 185, 165]
}

ipl_df = pd.DataFrame(data)

# %%
#1. Basic Data Exploration

print(ipl_df.head())

# View the first few rows

print(ipl_df.info()) # Get information about columns and data types
# Out:
#    season team1 team2 winner       city player_of_match  runs_scored
# 0    2023    MI   CSK     MI     Mumbai    Rohit Sharma          160
# 1    2023   CSK   RCB    CSK    Chennai        MS Dhoni          150
# 2    2023   RCB    MI     MI  Bangalore     Virat Kohli          175
# 3    2022    MI   KKR     MI    Kolkata  Jasprit Bumrah          150
# 4    2022  KXIP   CSK    KKR    Chennai   Andre Russell          200
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   season           9 non-null      int64
#  1   team1            9 non-null      object
#  2   team2            9 non-null      object
#  3   winner           9 non-null      object
#  4   city             9 non-null      object
#  5   player_of_match  9 non-null      object
#  6   runs_scored      9 non-null      int64
# dtypes: int64(2), object(5)
# memory usage: 636.0+ bytes
# None

# %%
#2. Team Performance

team_wins = ipl_df['winner'].value_counts()

print("\nTeam Wins: \n", team_wins)
# Out:
# Team Wins:
#  winner
# MI     4
# CSK    2
# KKR    1
# DC     1
# RCB    1
# Name: count, dtype: int64

# %%
#3. Player of the Match Analysis

player_of_match_counts = ipl_df['player_of_match'].value_counts()
print("\nPlayer of the Match Counts: \n", player_of_match_counts)
# Out:
# Player of the Match Counts:
#  player_of_match
# Rohit Sharma       1
# MS Dhoni           1
# Virat Kohli        1
# Jasprit Bumrah     1
# Andre Russell      1
# Ravindra Jadeja    1
# Rishabh Pant       1
# AB de Villiers     1
# Kieron Pollard     1
# Name: count, dtype: int64

# %%
#4. Runs Scored Analysis

average_runs_per_match = ipl_df['runs_scored'].mean()

print("\nAverage Runs Scored per Match:", average_runs_per_match)
# Out:
# Average Runs Scored per Match: 172.55555555555554

# %%
#1. Bar Chart of Team Wins

import matplotlib.pyplot as plt
import seaborn as sns

#1. Bar Chart of Team Wins

plt.figure(figsize=(10, 6))

sns.countplot(x='winner', data=ipl_df)

plt.title('Number of wins by Team')

plt.xlabel('Team')

plt.ylabel('Number of Wins')

plt.show()

plt.xlabel('Team')

plt.ylabel('Number of Wins')

plt.show()

# %%
#2. Histogram of Runs Scored

plt.figure(figsize=(8, 5))

# Changed 'bins-8' to 'bins=8' to specify the number of bins
plt.hist(ipl_df['runs_scored'], bins=8)

plt.title('Distribution of Runs Scored per Match')

#2. Histogram of Runs Scored

import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))

plt.hist(ipl_df['runs_scored'], bins=8)

plt.title('Distribution of Runs Scored per Match')

plt.xlabel('Runs Scored')

plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# Project 2: Exploring Trends in Indian Demographics

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample Indian Demographics Data (Replace with real data from Census of India)

data = {
    "state": ["Maharashtra", "Uttar Pradesh", "Bihar", "West Bengal", "Tamil Nadu", "Madhya Pradesh", "Rajasthan", "Karnataka", "Gujarat", "Andhra Pradesh"],
    "population": [123144223, 237882725, 124799926, 99600103, 77841287, 85014723, 78032689, 67563935, 64357546, 53081393],
    "literacy_rate": [82.9, 73.0, 61.8, 77.1, 80.3, 78.6, 67.1, 75.6, 79.3, 67.4],
    "rural_population_percent": [54.3, 77.7, 88.7, 68.1, 51.7, 72.4, 75.1, 61.3, 57.4, 66.6]
}

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample Indian Demographics Data (Replace with real data from Census of India)

data = {
    "state": ["Maharashtra", "Uttar Pradesh", "Bihar", "West Bengal", "Tamil Nadu", "Madhya Pradesh", "Rajasthan", "Karnataka", "Gujarat", "Andhra Pradesh"],
    "population": [123144223, 237882725, 124799926, 99600103, 77841287, 85014723, 78032689, 67563935, 64357546, 53081393],
    "literacy_rate": [82.9, 73.0, 61.8, 77.1, 80.3, 78.6, 67.1, 75.6, 79.3, 67.4],
    "rural_population_percent": [54.3, 77.7, 88.7, 68.1, 51.7, 72.4, 75.1, 61.3, 57.4, 66.6]
}

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample Indian Demographics Data (Replace with real data from Census of India)

data = {
    "state": ["Maharashtra", "Uttar Pradesh", "Bihar", "West Bengal", "Tamil Nadu", "Madhya Pradesh", "Rajasthan", "Karnataka", "Gujarat", "Andhra Pradesh"],
    "population": [123144223, 237882725, 124799926, 99600103, 77841287, 85014723, 78032689, 67563935, 64357546, 53081393],
    "literacy_rate": [82.9, 73.0, 61.8, 77.1, 80.3, 78.6, 67.1, 75.6, 79.3, 67.4],
    "rural_population_percent": [54.3, 77.7, 88.7, 68.1, 51.7, 72.4, 75.1, 61.3, 57.4, 66.6]
}

demographics_df = pd.DataFrame(data)
import matplotlib.pyplot as plt
import seaborn as sns

# Sample Indian Demographics Data (Replace with real data from Census of India)

data = {
    "state": ["Maharashtra", "Uttar Pradesh", "Bihar", "West Bengal", "Tamil Nadu", "Madhya Pradesh", "Rajasthan", "Karnataka", "Gujarat", "Andhra Pradesh"],
    "population": [123144223, 237882725, 124799926, 99600103, 77841287, 85014723, 78032689, 67563935, 64357546, 53081393],
    "literacy_rate": [82.9, 73.0, 61.8, 77.1, 80.3, 78.6, 67.1, 75.6, 79.3, 67.4],
    "rural_population_percent": [54.3, 77.7, 88.7, 68.1, 51.7, 72.4, 75.1, 61.3, 57.4, 66.6]
}

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample Indian Demographics Data (Replace with real data from Census of India)

data = {
    "state": ["Maharashtra", "Uttar Pradesh", "Bihar", "West Bengal", "Tamil Nadu", "Madhya Pradesh", "Rajasthan", "Karnataka", "Gujarat", "Andhra Pradesh"],
    "population": [123144223, 237882725, 124799926, 99600103, 77841287, 85014723, 78032689, 67563935, 64357546, 53081393],
    "literacy_rate": [82.9, 73.0, 61.8, 77.1, 80.3, 78.6, 67.1, 75.6, 79.3, 67.4],
    "rural_population_percent": [54.3, 77.7, 88.7, 68.1, 51.7, 72.4, 75.1, 61.3, 57.4, 66.6]
}

demographics_df = pd.DataFrame(data)

# %%
#1. Basic Data Exploration

print(demographics_df.head())

#1. Basic Data Exploration

print(demographics_df.head())

print(demographics_df.info())

#2. Population Analysis

total_population = demographics_df['population'].sum()
print("\nTotal Population of the Listed States:", total_population)

#3. Literacy Rate Analysis

average_literacy_rate = demographics_df['literacy_rate'].mean()
print("\nAverage Literacy Rate:", average_literacy_rate)

#4. Correlation between Literacy Rate and Rural Population

correlation = demographics_df['literacy_rate'].corr(demographics_df['rural_population_percent'])
print("\nCorrelation between Literacy Rate and Rural Population Percentage:", correlation)
# Out:
#            state  population  literacy_rate  rural_population_percent
# 0    Maharashtra   123144223           82.9                      54.3
# 1  Uttar Pradesh   237882725           73.0                      77.7
# 2          Bihar   124799926           61.8                      88.7
# 3    West Bengal    99600103           77.1                      68.1
# 4     Tamil Nadu    77841287           80.3                      51.7
#            state  population  literacy_rate  rural_population_percent
# 0    Maharashtra   123144223           82.9                      54.3
# 1  Uttar Pradesh   237882725           73.0                      77.7
# 2          Bihar   124799926           61.8                      88.7
# 3    West Bengal    99600103           77.1                      68.1
# 4     Tamil Nadu    77841287           80.3                      51.7
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   state                     10 non-null     object
#  1   population                10 non-null     int64
#  2   literacy_rate             10 non-null     float64
#  3   rural_population_percent  10 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 452.0+ bytes
# None
#
# Total Population of the Listed States: 1011318550
#
# Average Literacy Rate: 74.30999999999997
#
# Correlation between Literacy Rate and Rural Population Percentage: -0.8036329628976635

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Bar Chart of Population by State
plt.figure(figsize=(12, 6))
sns.barplot(x='state', y='population', data=demographics_df)

plt.title('Population by State')
plt.xlabel("State")
plt.ylabel('Population')
plt.xticks(rotation=45)  # Correct way to rotate labels

plt.show()

# %%
#2. Scatter Plot of Literacy Rate vs. Rural Population

import matplotlib.pyplot as plt
import seaborn as sns

#2. Scatter Plot of Literacy Rate vs. Rural Population

plt.figure(figsize=(8, 6))

sns.scatterplot(x='literacy_rate', y='rural_population_percent', data=demographics_df)

plt.title('Literacy Rate vs. Rural Population Percentage')

plt.xlabel('Literacy Rate (%)')

plt.ylabel('Rural Population (%)')

plt.show()

plt.xlabel('Literacy Rate (%)')

plt.ylabel('Rural Population (%)')

plt.show()

# %% [markdown]
# Project 3: Examining Air Quality in Indian Cities

# %%
import pandas as pd

import matplotlib.pyplot as plt

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample Air Quality Data for Indian Cities (Replace with real data from CPCB)
data = {
    'city': ['Delhi', 'Mumbai', 'Kolkata', 'Chennai', 'Bangalore', 'Hyderabad', 'Pune', 'Ahmedabad', 'Jaipur', 'Lucknow'],
    'date': pd.to_datetime(['2023-01-15', '2023-01-15', '2023-01-15', '2023-01-15', '2023-01-15', '2023-01-15', '2023-01-15', '2023-01-15', '2023-01-15', '2023-01-15']),
    'pm25': [250, 120, 180, 90, 70, 150, 110, 160, 200, 140],
    'no2': [80, 58, 60, 40, 30, 70, 45, 65, 90, 55],
    'so2': [30, 20, 25, 15, 10, 25, 18, 28, 35, 22]
}

air_quality_df = pd.DataFrame(data)
import matplotlib.pyplot as plt
import seaborn as sns

# Sample Air Quality Data for Indian Cities (Replace with real data from CPCB)
data = {
    'city': ['Delhi', 'Mumbai', 'Kolkata', 'Chennai', 'Bangalore', 'Hyderabad', 'Pune', 'Ahmedabad', 'Jaipur', 'Lucknow'],
    'date': pd.to_datetime(['2023-01-15', '2023-01-15', '2023-01-15', '2023-01-15', '2023-01-15', '2023-01-15', '2023-01-15', '2023-01-15', '2023-01-15', '2023-01-15']),
    'pm25': [250, 120, 180, 90, 70, 150, 110, 160, 200, 140],
    'no2': [80, 58, 60, 40, 30, 70, 45, 65, 90, 55],
    'so2': [30, 20, 25, 15, 10, 25, 18, 28, 35, 22]
}

air_quality_df = pd.DataFrame(data)

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample Air Quality Data for Indian Cities (Replace with real data from CPCB)
data = {
    'city': ['Delhi', 'Mumbai', 'Kolkata', 'Chennai', 'Bangalore', 'Hyderabad', 'Pune', 'Ahmedabad', 'Jaipur', 'Lucknow'],
    'date': pd.to_datetime(['2023-01-15', '2023-01-15', '2023-01-15', '2023-01-15', '2023-01-15', '2023-01-15', '2023-01-15', '2023-01-15', '2023-01-15', '2023-01-15']),
    'pm25': [250, 120, 180, 90, 70, 150, 110, 160, 200, 140],
    'no2': [80, 58, 60, 40, 30, 70, 45, 65, 90, 55],
    'so2': [30, 20, 25, 15, 10, 25, 18, 28, 35, 22]
}

air_quality_df = pd.DataFrame(data)

# %%
#1. Basic Data Exploration

print(air_quality_df.head())

print(air_quality_df.info())
# Out:
#         city       date  pm25  no2  so2
# 0      Delhi 2023-01-15   250   80   30
# 1     Mumbai 2023-01-15   120   58   20
# 2    Kolkata 2023-01-15   180   60   25
# 3    Chennai 2023-01-15    90   40   15
# 4  Bangalore 2023-01-15    70   30   10
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   city    10 non-null     object
#  1   date    10 non-null     datetime64[ns]
#  2   pm25    10 non-null     int64
#  3   no2     10 non-null     int64
#  4   so2     10 non-null     int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 532.0+ bytes
# None

# %%
#2. PM2.5 Analysis

average_pm25 = air_quality_df['pm25'].mean()
print("\nAverage PM2.5 across cities:", average_pm25)
# Out:
# Average PM2.5 across cities: 147.0

# %%
#3. City with Highest NO2 Levels

city_highest_no2 = air_quality_df.loc[air_quality_df['no2'].idxmax(), 'city']
print("\nCity with highest NO2 levels:", city_highest_no2)
# Out:
# City with highest NO2 levels: Jaipur

# %%
#4. Correlation between Pollutants

correlation_pm25_no2 = air_quality_df['pm25'].corr(air_quality_df['no2'])
print("\nCorrelation between. PM2.5 and NO2:", correlation_pm25_no2)
# Out:
# Correlation between. PM2.5 and NO2: 0.8912770111841118

# %%
#1. Bar Chart of PM2.5 Levels by City

plt.figure(figsize=(12, 6))

sns.barplot(x='city', y='pm25', data air_quality_df) plt.title('PM2.5 Levels by City')

plt.xlabel('City')

plt.ylabel('PM2.5')

plt.xticks(rotation=45)

plt.show()
